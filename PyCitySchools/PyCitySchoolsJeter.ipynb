# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# ...

# %%
# Rename column titles 

renamed_school_data_complete_df = school_data_complete.rename(columns = {"student_name": "Student Name", "school_name": "School Name",
                                                                        "reading_score": "Reading Score", "math_score": "Math Score",
                                                                        "gender": "Gender", "grade":"Grade", "type":"School Type", 
                                                                         "size": "# of Students", "budget":"Budget"})

#renamed_school_data_complete_df["Overall Score"] = (renamed_school_data_complete_df["Reading Score"]+renamed_school_data_complete_df["Math Score"])/2
#renamed_school_data_complete_df.head()
renamed_school_data_complete_df.head()
# Out:
#    Student ID       Student Name Gender Grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    Reading Score  Math Score  School ID School Type  # of Students   Budget
# 0             66          79          0    District           2917  1910635
# 1             94          61          0    District           2917  1910635
# 2             90          60          0    District           2917  1910635
# 3             67          58          0    District           2917  1910635
# 4             97          84          0    District           2917  1910635

# %%
# Calculate the total number of schools, number of students, and total budget

school_count = len(school_data["school_name"])
student_count = len(student_data["Student ID"])
budget_total = school_data["budget"].sum()
format_budget_total = "${:,.2f}".format(budget_total)
#print(f"Number of Schools: {school_count}")
#print(f"Number of Students: {student_count}")
#print(f"Total Budget: {format_budget_total}")

# Calculate the average math score and average reading score
average_math_score = round(renamed_school_data_complete_df["Math Score"].mean(), 1)
average_reading_score = round(renamed_school_data_complete_df["Reading Score"].mean(), 1)
#print(f"Average Math Score: {average_math_score}")
#print(f"Average Reading Score: {average_reading_score}")

# Calculate the percentage of students with a passing math score and a passing reading score (70 or greater).
# David Jenkins (TA) helped with syntax for count of passing students

pass_read_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Reading Score"] >= 70]['Reading Score'].count()   
pass_math_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Math Score"]>=70]['Math Score'].count()  
pass_overall_count = renamed_school_data_complete_df.loc[(renamed_school_data_complete_df["Math Score"]>=70) & (renamed_school_data_complete_df["Reading Score"]>= 70)]["Student Name"].count()  
#print(f"Count passing reading: {pass_read_count}"
#print(f"Count passing math: {pass_math_count}")

pass_math = pass_math_count/student_count
percent_pass_math = "{:.0%}".format(pass_math)
pass_read = pass_read_count/student_count
percent_pass_read = "{:.0%}".format(pass_read)
#print(percent_pass_math)
#print(percent_pass_read)

      
# Calculate the percentage of students who passed math and reading (% Overall Passing)
# Insert Column of "Overall Score" which is the average score of the Reading & Math scores

print(pass_overall_count)

 
# Calculate count of students passing Overall

print(pass_overall_count)
pass_overall = pass_overall_count/student_count
percent_pass_overall = "{:.0%}".format(pass_overall)
print(percent_pass_overall)
# Out:
# 25528
# 25528
# 65%

# %%
#Create a dataframe to hold the above results  Optional: give the displayed data cleaner formatting
distract_summary_df =pd.DataFrame({
    "Total School": [school_count],
    "Total Students": [student_count],
    "Total Budget": [format_budget_total],
    "Average Math Score": [average_math_score],
    "Average Reading Score": [average_reading_score],
    "% Passing Math": [percent_pass_math],
    "% Passing Reading": [percent_pass_read],
    "% Passing Overall": [percent_pass_overall]
}) 
distract_summary_df.head()

# Note: Check Overall percentage math.
# Out:
#    Total School  Total Students    Total Budget  Average Math Score  \
# 0            15           39170  $24,649,428.00                79.0
#
#    Average Reading Score % Passing Math % Passing Reading % Passing Overall
# 0                   81.9            75%               86%               65%

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## School Summary

# %%
# renamed_school_data_complete_df
grouped_school_df = renamed_school_data_complete_df.groupby(['School Name'])

school_avg_reading = round(grouped_school_df["Reading Score"].mean(), 1)
school_avg_math = grouped_school_df["Math Score"].mean()
school_count_students = grouped_school_df["Student ID"].count()


# Budget
school_budget = grouped_school_df["Budget"].max()

# needed to calc percentages - Andrew Perez helped me with this syntax
school_pass_math_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Math Score"]>69].groupby("School Name")
school_pass_reading_count = renamed_school_data_complete_df[renamed_school_data_complete_df["Reading Score"] >= 70].groupby("School Name")
school_pass_overall_count = renamed_school_data_complete_df[(renamed_school_data_complete_df["Reading Score"] >= 70) & (renamed_school_data_complete_df["Math Score"] >= 70)].groupby("School Name")


#Calculate the percentage of students with a passing math, reading & overall score (70 or greater) - Doris Meirs helped me find the sytax error by sharing her code.
school_pass_math_percent= school_pass_math_count['Student ID'].count()*100/school_count_students
school_pass_reading_percent = school_pass_reading_count['Student ID'].count()*100/school_count_students
school_pass_overall_percent = school_pass_overall_count['Student ID'].count()*100/school_count_students

# To format output on table later
#school_pass_math_percent = grouped_school_df["% Passing Math"].count()
#format_school_budget ="${:,.2f}".format(school_budget)
 
# Insert "School Type" into summary data frame.  Kelly Olien posted the syntax on Slack "Ask the Class".  I was missing .first()
school_type= grouped_school_df["School Type"].first()
   
#generate data frame

grouped_school_df = pd.DataFrame({"Number of Students": school_count_students,
                                  "Average Reading Scores": school_avg_reading,
                                  "Average Math Scores": school_avg_math,
                                  "Percent Passing Reading": school_pass_reading_percent,
                                  "Percent Passing Math": school_pass_math_percent,
                                  "Percent Passing Overall": school_pass_overall_percent,
                                  "Budget": school_budget,
                                  "School Type": school_type
                                 })

grouped_school_df.head()
# Out:
#                       Number of Students  Average Reading Scores  \
# School Name
# Bailey High School                  4976                    81.0
# Cabrera High School                 1858                    84.0
# Figueroa High School                2949                    81.2
# Ford High School                    2739                    80.7
# Griffin High School                 1468                    83.8
#
#                       Average Math Scores  Percent Passing Reading  \
# School Name
# Bailey High School              77.048432                81.933280
# Cabrera High School             83.061895                97.039828
# Figueroa High School            76.711767                80.739234
# Ford High School                77.102592                79.299014
# Griffin High School             83.351499                97.138965
#
#                       Percent Passing Math  Percent Passing Overall   Budget  \
# School Name
# ...

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort and display the top five performing schools by % overall passing.
top_overall_passing_performers= grouped_school_df.sort_values(by=['Percent Passing Overall'],ascending=False, inplace=True)

grouped_school_df.head(5)
# Out:
#                      Number of Students  Average Reading Scores  \
# School Name
# Cabrera High School                1858                    84.0
# Thomas High School                 1635                    83.8
# Griffin High School                1468                    83.8
# Wilson High School                 2283                    84.0
# Pena High School                    962                    84.0
#
#                      Average Math Scores  Percent Passing Reading  \
# School Name
# Cabrera High School            83.061895                97.039828
# Thomas High School             83.418349                97.308869
# Griffin High School            83.351499                97.138965
# Wilson High School             83.274201                96.539641
# Pena High School               83.839917                95.945946
#
#                      Percent Passing Math  Percent Passing Overall   Budget  \
# School Name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Sort and display the five worst-performing schools by % overall passing

bottom_overall_passing_performers= grouped_school_df.sort_values(by=['Percent Passing Overall'],ascending=True, inplace=True)

grouped_school_df.head(5)
# Out:
#                        Number of Students  Average Reading Scores  \
# School Name
# Rodriguez High School                3999                    80.7
# Figueroa High School                 2949                    81.2
# Huang High School                    2917                    81.2
# Hernandez High School                4635                    80.9
# Johnson High School                  4761                    81.0
#
#                        Average Math Scores  Percent Passing Reading  \
# School Name
# Rodriguez High School            76.842711                80.220055
# Figueroa High School             76.711767                80.739234
# Huang High School                76.629414                81.316421
# Hernandez High School            77.289752                80.862999
# Johnson High School              77.072464                81.222432
#
#                        Percent Passing Math  Percent Passing Overall   Budget  \
# School Name
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Phil the instructor helped provide the syntax.  This is average reading scores by grade.  Math is below.

nine_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "9th",:]
tenth_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "10th",:]
eleventh_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "11th",:]
twelfth_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "12th",:]

grouped_ninth_grade = nine_grade_df.groupby("School Name")
average_reading_scores_ninth_grade = round(grouped_ninth_grade["Reading Score"].mean(), 1)

grouped_tenth_grade = tenth_grade_df.groupby("School Name")
average_reading_scores_tenth_grade = round(grouped_tenth_grade["Reading Score"].mean(), 1)

grouped_eleventh_grade = eleventh_grade_df.groupby("School Name")
average_reading_scores_eleventh_grade = round(grouped_eleventh_grade["Reading Score"].mean(), 1)

grouped_twelfth_grade = twelfth_grade_df.groupby("School Name")
average_reading_scores_twelfth_grade = round(grouped_twelfth_grade["Reading Score"].mean(), 1)


# Build table to display reading scores by grade.  This is my own work

reading_score_school_df = pd.DataFrame({"9th Grade": average_reading_scores_ninth_grade,
                                        "10th Grade": average_reading_scores_tenth_grade,
                                        "11th Grade": average_reading_scores_eleventh_grade,
                                        "12th Grade": average_reading_scores_twelfth_grade
                                       })


reading_score_school_df.head(15)
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# School Name
# Bailey High School          81.3        80.9        80.9        80.9
# Cabrera High School         83.7        84.3        83.8        84.3
# Figueroa High School        81.2        81.4        80.6        81.4
# Ford High School            80.6        81.3        80.4        80.7
# Griffin High School         83.4        83.7        84.3        84.0
# Hernandez High School       80.9        80.7        81.4        80.9
# Holden High School          83.7        83.3        83.8        84.7
# Huang High School           81.3        81.5        81.4        80.3
# Johnson High School         81.3        80.8        80.6        81.2
# Pena High School            83.8        83.6        84.3        84.6
# Rodriguez High School       81.0        80.6        80.9        80.4
# Shelton High School         84.1        83.4        84.4        82.8
# ...

# %% [markdown]
# ## Reading Score by Grade
#
# * Perform the same operations as above for reading scores

# %%
# This is average math scores by grade (not reading scores)

nine_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "9th",:]
tenth_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "10th",:]
eleventh_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "11th",:]
twelfth_grade_df = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Grade"] == "12th",:]

grouped_ninth_grade = nine_grade_df.groupby("School Name")
average_math_scores_ninth_grade = round(grouped_ninth_grade["Math Score"].mean(), 1)

grouped_tenth_grade = tenth_grade_df.groupby("School Name")
average_math_scores_tenth_grade = round(grouped_tenth_grade["Math Score"].mean(), 1)

grouped_eleventh_grade = eleventh_grade_df.groupby("School Name")
average_math_scores_eleventh_grade = round(grouped_eleventh_grade["Math Score"].mean(), 1)

grouped_twelfth_grade = twelfth_grade_df.groupby("School Name")
average_math_scores_twelfth_grade = round(grouped_twelfth_grade["Math Score"].mean(), 1)


# Build table to display reading scores by grade

math_score_school_df = pd.DataFrame({"9th Grade": average_math_scores_ninth_grade,
                                        "10th Grade": average_math_scores_tenth_grade,
                                        "11th Grade": average_math_scores_eleventh_grade,
                                        "12th Grade": average_math_scores_twelfth_grade
                                       })


math_score_school_df.head(15)
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# School Name
# Bailey High School          77.1        77.0        77.5        76.5
# Cabrera High School         83.1        83.2        82.8        83.3
# Figueroa High School        76.4        76.5        76.9        77.2
# Ford High School            77.4        77.7        76.9        76.2
# Griffin High School         82.0        84.2        83.8        83.4
# Hernandez High School       77.4        77.3        77.1        77.2
# Holden High School          83.8        83.4        85.0        82.9
# Huang High School           77.0        75.9        76.4        77.2
# Johnson High School         77.2        76.7        77.5        76.9
# Pena High School            83.6        83.4        84.3        84.1
# Rodriguez High School       76.9        76.6        76.4        77.7
# Shelton High School         83.4        82.9        83.4        83.8
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
# create bins
bins =[0,1046265, 1319574, 2228999, 3124930]

# Labels foor bins
spending_labels = ["Q1 (<$1.04M)", "Q2 ($1.04M-$13.1M)", "Q3 ($13.1M-$22.2M)", "Q4 (>$22.2M)"]

#slice the data and place into bins code check
#pd.cut(renamed_school_data_complete_df["Budget"],bins, labels=spending_labels).head()

# slice the data and place into bins & put data into a new column
renamed_school_data_complete_df["Spending Quartile"] = pd.cut(renamed_school_data_complete_df["Budget"],bins, labels=spending_labels) 
#renamed_school_data_complete_df.head()

#category by Spend Group
spending_group = renamed_school_data_complete_df.groupby("Spending Quartile")

#print(spending_group["Student ID"].count())

spending_group_avg_reading = round(spending_group["Reading Score"].mean(),1)
spending_group_avg_math = round(spending_group["Math Score"].mean(), 1)                                   
spending_group_studend_count = spending_group["Student ID"].count()



#calculate pecent passing math
spending_group_pass_math_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Math Score"]>69].groupby("Spending Quartile")
spending_group_pass_math_percent= round(spending_group_pass_math_count['Student ID'].count()*100/spending_group_studend_count, 1)

spending_group_pass_read_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Reading Score"]>69].groupby("Spending Quartile")
spending_group_pass_read_percent= round(spending_group_pass_math_count['Student ID'].count()*100/spending_group_studend_count,1)

spending_group_pass_overall_count = renamed_school_data_complete_df[(renamed_school_data_complete_df["Reading Score"] >= 70) & (renamed_school_data_complete_df["Math Score"] >= 70)].groupby("Spending Quartile")
spending_group_pass_overall_percent= round(spending_group_pass_overall_count['Student ID'].count()*100/spending_group_studend_count,1)


spending_group_stats_df = pd.DataFrame({"Average Math Score": spending_group_avg_math,
                                        "Average Reading Score": spending_group_avg_reading,
                                        "Percent Passing Math": spending_group_pass_math_percent,
                                        "Percent Passing Reading": spending_group_pass_read_percent,
                                        "Percent Passing Overall": spending_group_pass_overall_percent
                                       })

spending_group_stats_df.head()

# needed to calc percentages - Andrew Perez helped me with this syntax
#school_pass_math_count = renamed_school_data_complete_df.loc[renamed_school_data_complete_df["Math Score"]>69].groupby("School Name")
#school_pass_reading_count = renamed_school_data_complete_df[renamed_school_data_complete_df["Reading Score"] >= 70].groupby("School Name")
#school_pass_overall_count = renamed_school_data_complete_df[(renamed_school_data_complete_df["Reading Score"] >= 70) & (renamed_school_data_complete_df["Math Score"] >= 70)].groupby("School Name")


#Calculate the percentage of students with a passing math, reading & overall score (70 or greater) - Doris Meirs helped me find the sytax error by sharing her code.
#school_pass_math_percent= school_pass_math_count['Student ID'].count()*100/school_count_students
#school_pass_reading_percent = school_pass_reading_count['Student ID'].count()*100/school_count_students
#school_pass_overall_percent = school_pass_overall_count['Student ID'].count()*100/school_count_students
# Out:
#                     Average Math Score  Average Reading Score  \
# Spending Quartile
# Q1 (<$1.04M)                      83.5                   83.9
# Q2 ($1.04M-$13.1M)                83.3                   83.9
# Q3 ($13.1M-$22.2M)                76.8                   81.0
# Q4 (>$22.2M)                      77.1                   80.9
#
#                     Percent Passing Math  Percent Passing Reading  \
# Spending Quartile
# Q1 (<$1.04M)                        93.5                     93.5
# Q2 ($1.04M-$13.1M)                  93.8                     93.8
# Q3 ($13.1M-$22.2M)                  66.6                     66.6
# Q4 (>$22.2M)                        66.5                     66.5
#
#                     Percent Passing Overall
# Spending Quartile
# Q1 (<$1.04M)                           90.6
# Q2 ($1.04M-$13.1M)                     90.5
# Q3 ($13.1M-$22.2M)                     53.7
# Q4 (>$22.2M)                           53.7

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
